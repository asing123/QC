# %% [markdown]
# ## Qubits, the Bloch Sphere, and Basis States
#
# - #### Hands-on Experiential Learning <font color="red">for the Software Engineer</font>

# %% [markdown]
# ![](img/QC_Math_Banner.png "")
#
# <font color="red">**Notice**</font>: All materials herein were <font color="red">**curated**</font> by **Matthew R. Versaggi (profversaggi@gmail.com)** and are released into the open source to foster growth and welfare of expanding the Quantum Computing domain - the only obligation one incurs when using, copying, distributing or referencing this is to kindly reference the author and send me an email so I know how useful the material is to you.
#
# #### <font color="red">Recommendations</font>:
#
# > **<font color="blue">It's highly recommended to take structured QC Math courses <font color="red">like</font>:</font>**
# > #### Math Prerequisites for Quantum Computing
# > - https://www.udemy.com/course/mathematics-prerequisites-for-quantum-computing-and-quantum-physics/
#
# > #### Advanced Math for Quantum Computing
# > - https://www.udemy.com/course/qc201-advanced-math-for-quantum-computing-mathematics-physics/
#
#
#
# #### <font color="red">Materials Inspiration and Author(s)</font>:
#
# > **<font color="blue">Amelie Schreiber</font>**
# - Article: https://towardsdatascience.com/quantum-computing-for-the-newb-5e0737e3ca4
# - Course: https://the-singularity-research.github.io/linear_algebra_for_quantum_computing/
# - GitHub: https://github.com/The-Singularity-Research/linear_algebra_for_quantum_computing
#
# > **<font color="blue">QWorld</font>**
# - Site: https://qworld.lu.lv/
# - GitLab: https://gitlab.com/qkitchen/basics-of-quantum-computing

# %% [markdown]
# ## Installs and Imports
#
# We will need to install Qiskit, IBM's quantum computing language. Then we will need to import qiskits tools for creating Bloch sphere representations of qubits.

# %%
# pip install qiskit

# %%
import numpy as np
from qiskit import *
from qiskit.visualization import plot_bloch_vector

# %matplotlib inline

# %% [markdown]
# ### <font color="red">**Why this is important**</font>:
#
# ## Qubits, the Bloch Sphere, and Basis States

# %% [markdown]
# #### Qubits are the basic unit of computation in a quantum computer, much like bits are the basic unit of computation in a "classical" computer.
#
#
# > In bit based computing we have silicon chips with transistors which serve as "on/off" switches that serve as building blocks for complex systems of logic gates implementing Boolean logic.
#
# - In a quantum computer, these "on/off" bits represented by strings of 0s and 1s are replaced by **qubits**.
#
# - Qubits behave much differently from classical bits, but any classical computation involving bits can still be implemented on a quantum system of qubits.
#
# > However, much more can be done qubits. They provide computational abilities that bits, classical computing, and classical information processing simply cannot replicate or accurately simulate.
# - In some cases there are quantum information processes which provide a new paradigm for understanding information theory and computational complexity.
#
#
# **Here we will focus on the basics** and leave quantum complexity and subjects like entanglement entropy for the appendix at the end of the book on **tensor networks**.
#
# **Qubits have many representations**, the most common of them being as **a $2$-dimensional complex unit vector**:
# - Vector of Complex Numbers
# - Unit Vector - a vector which has a magnitude of **<font color="red">one</font>**.
#
# <BR>
# <font color="blue">
# \begin{align}
# |\psi \rangle = \begin{pmatrix}
# \alpha \\ \beta
#     \end{pmatrix}, \quad \text{where } \sqrt{\langle \psi | \psi \rangle} = 1.
# \end{align}
#
# </font>
#
# <BR>
#
# From the **condition that the vector be of length one**, we can <font color="red">deduce</font> the following:
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \sqrt{\langle \psi | \psi \rangle} &= \begin{pmatrix} \alpha^*, & \beta^* \end{pmatrix}\begin{pmatrix} \alpha \\ \beta \end{pmatrix} \\
# &= \sqrt{\alpha^* \alpha+ \beta^* \beta}\\
# &= \sqrt{|\alpha|^2 +|\beta|^2} = 1 \implies |\alpha|^2 +|\beta|^2 = 1.
# \end{align}
#
# </font>
#
# <BR>
#
# **As a detailed explanation**, $\alpha$ and $\beta$ are **complex numbers** (elements of $\mathbb{C}$), and so the vector $|\psi \rangle \in \mathbb{C}^2$.
#
#
# The vectors representing qubit **[pure states](https://en.wikipedia.org/wiki/Quantum_state#Pure_states)** actually live on the **Riemann sphere** also called the **[complex projective line](https://en.wikipedia.org/wiki/Riemann_sphere#As_the_complex_projective_line)** $\mathbb{P}^1(\mathbb{C})$.
#
# > **The second representation**, which comes from the representation of pure states as points on the Riemann sphere and that is very common in the literature and in software packages for quantum computing is via the **[Bloch sphere](https://en.wikipedia.org/wiki/Bloch_sphere)**, named after the Nobel laureate and physicist [Felix Bloch](https://en.wikipedia.org/wiki/Felix_Bloch).
#
#
# Generally, <font color="red">the north pole</font> represents the **basis state**
#
# <BR>
#
# \begin{align}
# |0\rangle = \begin{pmatrix} 1\\0 \end{pmatrix}
# \end{align}
#
# <BR>
#
#
#
# We can visualize this in **Qiskit** as follows:

# %% [markdown]
# #### Display the Bloch Sphere in the Zero Ket State

# %%
plot_bloch_vector([0,0,1], title="Spin-Up")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Pauli Basis States
#
# In general we have the following <font color="red">**SIX basis states**</font> in terms of the "**Puali matrices**" to consider.
#
# <BR>
#
# ## <font color="red">Developmental Detour</Font> : Qubit / Bloch Sphere <font color="blue">Basis Elements</Font>
#
#
# > **Mathematical Basis** is an important concept to be aware of and understand as it's central to Qubit manipulations.
#
#
# There are **three** mathematical **basis elements** (aka. the **"endpoints" of the axis** to be "aware" of with the bloch sphere:
# - **Computational (<font color="red">Z</font>)**
# - **Hadamard (<font color="red">X</font>)**
# - **Circular (<font color="red">Y</font>)**
#
# ![vector-basis-space](img/vector-basis-space.png "")
#
#
# > <font color="red">**NOTE**</font>: The basis elements are the **endpoints of an axis**. For **example**, the basis elements for the *computational basis* are **|0>** and **|1>**, which correspond to the endpoints of the **Z-axis**.

# %% [markdown]
# ##  Spin-<font color="blue">UP</font> / Spin-<font color="blue">DOWN</font> (<font color="red">**Z**</font>-Axis)
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \text{spin-up}: \ |0\rangle &= \begin{pmatrix} 1\\0 \end{pmatrix} \\
# \text{spin-down}: \ |1\rangle & = \begin{pmatrix} 0\\1 \end{pmatrix}
# \end{align}
#
# <BR>
# </font>

# %% [markdown]
# ###  Spin-<font color="blue">UP</font> (<font color="red">**Z**</font>-Axis)

# %%
plot_bloch_vector([0,0,1], title="Spin-Up")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ###  Spin-<font color="blue">DOWN</font> (<font color="red">**Z**</font>-Axis)

# %%
plot_bloch_vector([0,0,-1], title="Spin-Down")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Spin-<font color="blue">RIGHT</font> / Spin-<font color="blue">LEFT</font> (<font color="red">**X**</font>-axis)
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \text{spin-right}: \ |r\rangle &= \begin{pmatrix} 1/\sqrt{2} \\ i/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle + i|1\rangle\right) \\
# \text{spin-left}: \ |l\rangle & = \begin{pmatrix} 1/\sqrt{2} \\ -i/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle - i|1\rangle\right)
# \end{align}
#
# </font>
#
# <BR>

# %% [markdown]
# ###  Spin-<font color="blue">RIGHT</font> (<font color="red">**X**</font>-Axis)

# %%
plot_bloch_vector([0,1,0], title="Spin-Right")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ###  Spin-<font color="blue">LEFT</font> (<font color="red">**X**</font>-Axis)

# %%
plot_bloch_vector([0,-1,0], title="Spin-Left")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Spin-<font color="blue">PLUS</font> / Spin-<font color="blue">MINUS</font> (<font color="red">**Y**</font>-axis)
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \text{spin +}: \ |+\rangle &= \begin{pmatrix} 1/\sqrt{2} \\ 1/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle + |1\rangle\right) \\
# \text{spin -}: \ |-\rangle & = \begin{pmatrix} 1/\sqrt{2} \\ -1/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle - |1\rangle\right)
# \end{align}
#
# </font>
# <BR>

# %% [markdown]
# ###  Spin-<font color="blue">Plus</font> (<font color="red">**Y**</font>-Axis)

# %%
plot_bloch_vector([1,0,0], title="Spin-Plus")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ###  Spin-<font color="blue">Minus</font> (<font color="red">**Y**</font>-Axis)

# %%
plot_bloch_vector([-1,0,0], title="Spin-Minus")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Arbitrary State Vectors

# %% [markdown]
# #### If we want to define an arbitrary state vector on the Bloch sphere we simply need to <font color="red">**define a unit vector in $3$-dimensional space**</font> as the <font color="blue">input state</font>.
#
#
# To do this:
#
# - Define any **$3$-dimensional vector**, then
# - Divide it by its **length (or norm)** - this will give a **vector of length one**
#
# > That can then be used as an **input** for Qiskit to plot on the Bloch sphere.
#
# #### An arbitrary pure state can be represented as some linear combination:
#
# <BR>
# <font color="blue">
#
# \begin{align}
# |\psi \rangle =
# \begin{pmatrix}
# \alpha \\ \beta
# \end{pmatrix} = \alpha |0\rangle + \beta |1\rangle
# \end{align}
#
#
# where <font color="blue"> $|\alpha|^2 + |\beta|^2 = 1$ </font>.
#
# <BR>

# %% [markdown]
# ### Define a 3-dimensional vector, and normalize it using Numpy

# %%
# Define a 3-dimensional vector
#
vect = np.array([1, -1, 1])


# Divide it by its length (or norm) using Numpy
#
psi = vect/(np.linalg.norm(vect))


# Display
print(psi)
# Out:
# [ 0.57735027 -0.57735027  0.57735027]

# %% [markdown]
# ### Now Plot it

# %%
# Plot psi on the Bloch sphere using Qiskit
#
plot_bloch_vector(psi, title="psi")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## Spherical Coordinates as State Vectors
#
# <BR>
#
# We could also use <font color="red">**spherical coordinates**</font> to define a <font color="blue">**unit vector**</font> that *always lies on the surface of the unit sphere in $3$-dimensions* (which is the Bloch sphere).
#
#
# > To do this, we choose a density operator **RHO**: <font color="red"> **$\rho = 1$** </font>, and then choose two angles **PHI**: $\phi \in [0, \pi]$ and **THETA**: $\theta \in [0, 2\pi]$.
#
# ### Formula:
#
# - **The Formula** for the <font color="red"> $x, y,$ and $z$ </font> coordinates are then:
#
# <font color="blue">
#
# \begin{align}
# x &= \rho \sin(\phi) \cos(\theta) \\
# y &= \rho \sin(\phi) \sin(\theta) \\
# z &= \rho \cos(\phi)
# \end{align}
#
# </font>
#
# <BR>
#
# ### Refresher:
#
# - **<font color="red">Points on the Qubit </font>** is represented by the (*greek letter*) **<font color="blue" size="5">Psi &psi;</font>** of the sphere.
# - **<font color="red">Magnitudes</font>** is represented by the angle (*greek letter*) **<font color="blue" size="5">"Theta" θ</font>** - on the **Vertical Plane (or Longitude)** of the sphere : **<font color="red">X</font>** axis and **<font color="red">Y</font>** axis rotations.
# - **<font color="red">Relative Phases</font>** is represented by the angle (*greek letter*) **<font color="blue" size="5">"Phi" &phi;**</font> - on the **Horizontal Plane (or Latitude)** of the sphere: **<font color="red">Z</font>** axis rotations.
#
# <BR>
#
# ![naked-qubit](img/naked-qubit.png "")
#
# <BR>

# %% [markdown]
# ### Refresher on Bloch SPhere and Basis States: <font color="blue">Bloch Sphere Playground Application</font>

# %%
# Bloch Sphere Playground Application
from IPython.display import IFrame
IFrame(src='https://javafxpert.github.io/grok-bloch/', width=950, height=700)
# Out:
#         <iframe
#             width="950"
#             height="700"
#             src="https://javafxpert.github.io/grok-bloch/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Let do an **example** with $\phi = 0$ and $\theta = 0$.
#
# > This should correspond to <font color="red">**spin-up**</font> since we get
#
# <BR>
# <font color="blue">
#
# \begin{align}
# x &= 0 \\
# y &= 0 \\
# z &= 1
# \end{align}
#
# </font>
#
# <BR>

# %% [markdown]
# ### Spin-UP
# - <font color="blue">Using: 𝑥, 𝑦,  and 𝑧  coordinate formulas</font>

# %%
#   𝑥, 𝑦,  and 𝑧 coordinate formulas

x = np.sin(0)*np.cos(0)
y = np.sin(0)*np.sin(0)
z = np.cos(0)

psi1 = np.array([x, y, z])

print("x=", x)
print("y=", y)
print("z=", z)
print("psi1=", psi1)
# Out:
# x= 0.0
# y= 0.0
# z= 1.0
# psi1= [0. 0. 1.]

# %%
# Plot psi on the Bloch sphere using Qiskit

plot_bloch_vector(psi1, title="psi1")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# Let's try to use spherical coordinates to create the **spin-down** state now.
#
# ### Spin-DOWN

# %%
x = np.sin(0)*np.cos(np.pi)
y = np.sin(0)*np.sin(np.pi)
z = np.cos(np.pi)

psi2 = np.array([x, y, z])

print("x=", x)
print("y=", y)
print("z=", z)
print("psi2=", psi2)
# Out:
# x= -0.0
# y= 0.0
# z= -1.0
# psi2= [-0.  0. -1.]

# %%
# Plot psi on the Bloch sphere using Qiskit

plot_bloch_vector(psi2, title="psi2")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ## <font color="blue">Six Basis States</font>
#
#
# > Let's define **the six basis states** in Python and *compute some things with them*.

# %%
# SPIN-UP
spin_up = np.matrix([[1], [0]])

# SPIN-DOWN
spin_down = np.matrix([[0], [1]])

# SPIN-RIGHT
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# SPIN-LEFT
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# SPIN-PLUS
spin_plus = (1/np.sqrt(2))*(spin_up + spin_down)

# SPIN-MINUS
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)


print('spin up:', spin_up)
print('spin down:', spin_down)
print('spin right:', spin_right)
print('spin left:', spin_left)
print('spin plus:', spin_plus)
print('spin minus:', spin_minus)
# Out:
# spin up: [[1]
#  [0]]
# spin down: [[0]
#  [1]]
# spin right: [[0.70710678+0.j        ]
#  [0.        +0.70710678j]]
# spin left: [[0.70710678+0.j        ]
#  [0.        -0.70710678j]]
# spin plus: [[0.70710678]
#  [0.70710678]]
# spin minus: [[ 0.70710678]
#  [-0.70710678]]

# %% [markdown]
# ### Compute some things with them

# %%
np.dot(spin_down.H, spin_down)
# Out:
# matrix([[1]])

# %%
np.dot(spin_left.H, spin_right)
# Out:
# matrix([[0.+0.j]])

# %% [markdown]
# # <font color="red">Graded Exercises</font>  for use <font color="blue">with structured courses.</font>
#
# ## Bloch Sphere
#
# #### <font color="blue">*This work will take some time, so block off enough time to adequately cover it*</font>.
#
#
# - Go through the **entire** JNB and complete each of the exercises, including any supplementary Video's - hand in completed <font color="red">**PDF**</font> from this JNB once finished.
#
#
# - Step through the code for **each** of the above exercises, make sure you can (1) execute it, and (2) know what it does.
#
#
# - <font color="blue">Complete Challenge Exercises below.</font> **(turn in the JNB)**

# %% [markdown]
# ## Exercises: Inner Products
# - **<font color="red">In Python</font>**.
#
# **Further down below**, you'll compute the following **inner products** (using Python) of the **Basis States** given the **reference materials** immediately below:
#
# <BR>
#
# <font color="blue">
# 1. $\langle 0 | 1 \rangle$ <BR>
# 2. $\langle 1 | 0 \rangle$ <BR>
# 3. $\langle 1 | 1 \rangle$ <BR>
# 4. $\langle r | l \rangle$ <BR>
# 5. $\langle l | r \rangle$ <BR>
# 6. $\langle r | r \rangle$ <BR>
# 7. $\langle l | l \rangle$ <BR>
# 8. $\langle + | - \rangle$ <BR>
# 9. $\langle + | r \rangle$ <BR>
# 10. $\langle - | l \rangle$ <BR>
# 11. $\langle 0 | r \rangle$ <BR>
# 12. $\langle l | 1 \rangle$ <BR>
# 13. $\langle 0 | + \rangle$ <BR>
# 14. $\langle - | - \rangle$ <BR>
# 15. $\langle - | r \rangle$ <BR>
#
# </font>
# <BR>

# %% [markdown]
# ## <font color="red">Reference Materials</font>

# %% [markdown]
# ###  Spin-<font color="blue">UP</font> / Spin-<font color="blue">DOWN</font> (<font color="red">**Z**</font>-Axis)
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \text{spin-up}: \ |0\rangle &= \begin{pmatrix} 1\\0 \end{pmatrix} \\
# \text{spin-down}: \ |1\rangle & = \begin{pmatrix} 0\\1 \end{pmatrix}
# \end{align}
#
# </font>

# %%
# SPIN-UP
spin_up = np.matrix([[1], [0]])

# SPIN-DOWN
spin_down = np.matrix([[0], [1]])

# %%
# spin_up
spin_up
# Out:
# matrix([[1],
#         [0]])

# %%
# spin_down
spin_down
# Out:
# matrix([[0],
#         [1]])

# %% [markdown]
# ### Spin-<font color="blue">RIGHT</font> / Spin-<font color="blue">LEFT</font> (<font color="red">**X**</font>-axis)
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \text{spin-right}: \ |r\rangle &= \begin{pmatrix} 1/\sqrt{2} \\ i/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle + i|1\rangle\right) \\
# \text{spin-left}: \ |l\rangle & = \begin{pmatrix} 1/\sqrt{2} \\ -i/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle - i|1\rangle\right)
# \end{align}
#
# </font>
#
# <BR>

# %%
# SPIN-RIGHT
spin_right = (1/np.sqrt(2))*(spin_up + 1j*spin_down)

# %%
# spin_right
spin_right
# Out:
# matrix([[0.70710678+0.j        ],
#         [0.        +0.70710678j]])

# %%
# SPIN-LEFT
spin_left = (1/np.sqrt(2))*(spin_up - 1j*spin_down)

# %%
# spin_left 
spin_left
# Out:
# matrix([[0.70710678+0.j        ],
#         [0.        -0.70710678j]])

# %% [markdown]
# ### Spin-<font color="blue">PLUS</font> / Spin-<font color="blue">MINUS</font> (<font color="red">**Y**</font>-axis)
#
# <BR>
# <font color="blue">
#
# \begin{align}
# \text{spin +}: \ |+\rangle &= \begin{pmatrix} 1/\sqrt{2} \\ 1/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle + |1\rangle\right) \\
# \text{spin -}: \ |-\rangle & = \begin{pmatrix} 1/\sqrt{2} \\ -1/\sqrt{2} \end{pmatrix} = \frac{1}{\sqrt{2}} \left(|0\rangle - |1\rangle\right)
# \end{align}
#
# </font>
# <BR>

# %%
# SPIN-PLUS
spin_plus = (1/np.sqrt(2))*(spin_up + spin_down)

# %%
# spin_plus
spin_plus
# Out:
# matrix([[0.70710678],
#         [0.70710678]])

# %%
# SPIN-MINUS
spin_minus = (1/np.sqrt(2))*(spin_up - spin_down)

# %%
# spin_minus
spin_minus
# Out:
# matrix([[ 0.70710678],
#         [-0.70710678]])

# %% [markdown]
# ## <font color="blue">Inner Products</font>
# **Inner Products** are a more *general case* of the **dot-product**, but *for most of our purposes, they can be thought of as the same thing*.
#
# > The **most basic case of an inner product** and the one we will use the most often can be thought of as the **product of a <font color="red">row</font> vector and a <font color="red">column</font> vector of the <font color="blue">same dimension</font>**:
#
# \begin{align} \langle A| = \begin{pmatrix}
# a_1, & a_2, & \cdots, & a_n
# \end{pmatrix}, \quad \quad
# |B\rangle = \begin{pmatrix}
# b_1 \\ b_2 \\ \vdots \\ b_n
# \end{pmatrix} \end{align}
#
# Taking the <font color="blue">**inner product**</font> of $\langle A|$ and $|B\rangle$ gives the following:
#
# <font color="blue">
#
# \begin{align} \langle A| B \rangle &= \begin{pmatrix}
# a_1, & a_2, & \cdots, & a_n
# \end{pmatrix}
# \begin{pmatrix}
# b_1 \\ b_2 \\ \vdots \\ b_n
# \end{pmatrix}\\
# &=
# a_1b_1 + a_2b_2 + \cdots + a_nb_n\\
# &= \sum_{i=1}^n a_ib_i
# \end{align}
#
# </font>
#
#
# <BR>
#
# ### Example:

# %%
# Define the 4x1 matrix version of a column vector (instead of using the np.array() version):

A = np.matrix([[1-1j], 
               [3], 
               [2j], 
               [5+1j]])

print(A)
# Out:
# [[1.-1.j]
#  [3.+0.j]
#  [0.+2.j]
#  [5.+1.j]]

# %% [markdown]
# #### Check shape

# %%
A.shape
# Out:
# (4, 1)

# %% [markdown]
# ### Compute the Hermitian Conjugate  (also called the <font color="red">Complex Conjugate</font>):

# %%
# Compute the Hermitian Conjugate  (also called the Complex conjugate):
A.H
# Out:
# matrix([[1.+1.j, 3.-0.j, 0.-2.j, 5.-1.j]])

# %% [markdown]
# ### Compute the <font color="red">inner product</font> $ \langle A|A \rangle $
# - Simply **multiply** the two matrix versions just computed using Numpy's DotProduct FN:

# %%
np.dot(A.H, A)
# Out:
# matrix([[41.+0.j]])

# %% [markdown]
# ## Problems (<font color="red">1-15</font>):
#
# ### <font color="blue">Compute the following inner products (in python) given the previous reference materials</font>:
#
# 1. $\langle 0 | 1 \rangle$
# 2. $\langle 1 | 0 \rangle$
# 3. $\langle 1 | 1 \rangle$
# 4. $\langle r | l \rangle$
# 5. $\langle l | r \rangle$
# 6. $\langle r | r \rangle$
# 7. $\langle l | l \rangle$
# 8. $\langle + | - \rangle$
# 9. $\langle + | r \rangle$
# 10. $\langle - | l \rangle$
# 11. $\langle 0 | r \rangle$
# 12. $\langle l | 1 \rangle$
# 13. $\langle 0 | + \rangle$
# 14. $\langle - | - \rangle$
# 15. $\langle - | r \rangle$

# %% [markdown]
# ### <font color="red">1</font>:  $\langle 0 | 1 \rangle$

# %%
print(np.dot(spin_up.H,spin_down))
# Out:
# [[0]]

# %% [markdown]
# ### <font color="red">2</font>:  $\langle 1 | 0 \rangle$

# %%
print(np.dot(spin_down.H,spin_up))
# Out:
# [[0]]

# %% [markdown]
# ### <font color="red">3</font>:  $\langle 1 | 1 \rangle$

# %%
print(np.dot(spin_down.H,spin_down))
# Out:
# [[1]]

# %% [markdown]
# ### <font color="red">4</font>:  $\langle r | l \rangle$

# %%
print(np.dot(spin_right.H,spin_left))
# Out:
# [[0.+0.j]]

# %% [markdown]
# ### <font color="red">5</font>:  $\langle l | r \rangle$

# %%
print(np.dot(spin_left.H,spin_right))
# Out:
# [[0.+0.j]]

# %% [markdown]
# ### <font color="red">6</font>:  $\langle r | r \rangle$

# %%
print(np.dot(spin_right.H,spin_right))
# Out:
# [[1.+0.j]]

# %% [markdown]
# ### <font color="red">7</font>:  $\langle l | l \rangle$

# %%
print(np.dot(spin_left.H,spin_left))
# Out:
# [[1.+0.j]]

# %% [markdown]
# ### <font color="red">8</font>:  $\langle + | - \rangle$

# %%
print(np.dot(spin_plus.H,spin_minus))
# Out:
# [[0.]]

# %% [markdown]
# ### <font color="red">9</font>:  $\langle + | r \rangle$

# %%
print(np.dot(spin_plus.H,spin_right))
# Out:
# [[0.5+0.5j]]

# %% [markdown]
# ### <font color="red">10</font>:  $\langle - | l \rangle$

# %%
print(np.dot(spin_minus.H,spin_left))
# Out:
# [[0.5+0.5j]]

# %% [markdown]
# ### <font color="red">11</font>:  $\langle 0 | r \rangle$

# %%
print(np.dot(spin_up.H,spin_right))
# Out:
# [[0.70710678+0.j]]

# %% [markdown]
# ### <font color="red">12</font>: $\langle l | 1 \rangle$

# %%
print(np.dot(spin_left.H,spin_down))
# Out:
# [[0.+0.70710678j]]

# %% [markdown]
# ### <font color="red">13</font>:  $\langle 0 | + \rangle$

# %%
print(np.dot(spin_up.H,spin_plus))
# Out:
# [[0.70710678]]

# %% [markdown]
# ### <font color="red">14</font>:  $\langle - | - \rangle$

# %%
print(np.dot(spin_minus.H,spin_minus))
# Out:
# [[1.]]

# %% [markdown]
# ### <font color="red">15</font>:  $\langle - | r \rangle$

# %%
print(np.dot(spin_minus.H,spin_right))
# Out:
# [[0.5-0.5j]]

# %% [markdown]
# ## Problems (<font color="red">16-20</font>):
#
# ### Plot the following states on the <font color="blue"> Bloch sphere using Qiskit for the given angles</font> <font color="blue"> $\phi$ </font>  and <font color="blue">$\theta$ </font> :

# %% [markdown]
# > #### <font color="red">If it helps</font>: remember that Pi radians is equal to 180 degrees
# - The below link is provided as a reference for the conversions.
# - https://www.quia.com/jg/321176list.html

# %% [markdown]
# ### <font color="red">REFERENCE</font>:  Display the Bloch Sphere in the Zero Ket State

# %% [markdown]
# <font color="red">**Spherical coordinates**</font> define a <font color="blue">**unit vector**</font> that *always lies on the surface of the unit sphere in $3$-dimensions* (which is the Bloch sphere).
#
#
# > To do this, we choose **$\rho = 1$**, and then choose two angles $\phi \in [0, \pi]$ and $\theta \in [0, 2\pi]$.
#
# - #### The $x$, $y$, and $z$ coordinates are then:
#
# <font color="blue">
#
# \begin{align}
# x &= \rho \sin(\phi) \cos(\theta) \\
# y &= \rho \sin(\phi) \sin(\theta) \\
# z &= \rho \cos(\phi)
# \end{align}
#
# </font>

# %% [markdown]
# ### **Example** with PHI: <font color="red"> $\phi$ </font> = <font color="blue">0</font>, and  THETA: <font color="red"> $\theta$ </font> = <font color="blue">0</font>.
#
#
# > This should correspond to <font color="red">**spin-up**</font>, since the above formulas for (**X,Y and Z**) provide:
#
# <font color="blue">
#
# \begin{align}
# x &= 0 \\
# y &= 0 \\
# z &= 1
# \end{align}
#
# </font>

# %% [markdown]
# ### Set PHI and THETA

# %%
phi = 0
theta = 0

print("Phi:", phi)
print("Theta:", theta)
# Out:
# Phi: 0
# Theta: 0

# %% [markdown]
# ### Use PHI and THETA to calculate X,Y and Z

# %%
#   𝑥, 𝑦,  and 𝑧 coordinate formulas

x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

# Set the unit vector:

unit_vector_spin_up = np.array([x, y, z])

print("x=", x)
print("y=", y)
print("z=", z)

print("unit_vector_spin_up=", unit_vector_spin_up)
# Out:
# x= 0.0
# y= 0.0
# z= 1.0
# unit_vector_spin_up= [0. 0. 1.]

# %% [markdown]
# ### Plot the Bloch Sphere

# %%
plot_bloch_vector(unit_vector_spin_up, title="Spin-Up")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ### <font color="red">16</font>: $\phi = \pi/2$, $\theta = -\pi/3$.
#
#
#
# - $\phi$ = pi/2 = 90dg
# - $\theta$ = (-pi/3) = -60dg
#
#
# > - The below link is provided as a reference for the conversions.
# > - https://www.quia.com/jg/321176list.html
#
#
# ### <font color="red">This first one is done for you</font>.

# %% [markdown]
# ### Set PHI and THETA

# %%
phi = 90
theta = -60

# %%
x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

unit_vector_problem_16 = np.array([x, y, z])

print("x=", x)
print("y=", y)
print("z=", z)
print("unit_vector_problem_16 =", unit_vector_problem_16)
# Out:
# x= -0.8514540268610132
# y= 0.2724996782953955
# z= -0.4480736161291701
# unit_vector_problem_16 = [-0.85145403  0.27249968 -0.44807362]

# %%
unit_vector_problem_16
# Out:
# array([-0.85145403,  0.27249968, -0.44807362])

# %%
type(unit_vector_problem_16)
# Out:
# numpy.ndarray

# %%
plot_bloch_vector(unit_vector_problem_16, title="unit_vector_problem_16")
# Out:
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %% [markdown]
# ### <font color="red">17</font>: $\phi$ = $-\pi/4$, $\theta$ = $-\pi/6$.

# %%
theta = -180/6 
phi = -180/4

x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

problem17 = np.array([x,y,z])

print("x=", x)
print("y=", y)
print("z=", z)

print("================")
print(problem17)
print("================")
print(type(problem17))

plot_bloch_vector(problem17, title = "problem17")
# Out:
# x= -0.13125310237384322
# y= -0.8407195912917853
# z= 0.5253219888177297
# ...
# [-0.1312531  -0.84071959  0.52532199]
# ...
# <class 'numpy.ndarray'>
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
# ...

# %% [markdown]
# ### <font color="red">18</font>: $\phi$ = $-\pi/2$, $\theta$ = $\pi/4$.

# %%
phi = -180/2 
theta = 180/4 

#=========define the array========="
x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

problem18 = np.array([x,y,z])
#============print vectors======""
print("x=", x)
print("y=", y)
print("z=", z)

print("================")
print(problem18)
print("================")
print(type(problem18))

#=========print bloch sphere================""
plot_bloch_vector(problem18, title = "problem18")
# Out:
# x= -0.4696361053190599
# y= -0.7607049119794573
# z= -0.4480736161291701
# ...
# [-0.46963611 -0.76070491 -0.44807362]
# ...
# <class 'numpy.ndarray'>
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
# ...

# %% [markdown]
# ### <font color="red">19</font>:  $\phi = \pi/3$, $\theta = -\pi$.

# %%
phi = 180/3 
theta = -180  

#=========define the array========="
x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

problem19 = np.array([x,y,z])
#============print vectors======""
print("x=", x)
print("y=", y)
print("z=", z)

print("================")
print(problem19)
print("================")
print(type(problem19))

#=========print bloch sphere================""
plot_bloch_vector(problem19, title = "problem19")
# Out:
# x= 0.1824169853544012
# y= -0.24419983249570681
# z= -0.9524129804151563
# ...
# [ 0.18241699 -0.24419983 -0.95241298]
# ...
# <class 'numpy.ndarray'>
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
# ...

# %% [markdown]
# ### <font color="red">20</font>:  $\phi = -\pi/6$, $\theta = -\pi/4$.

# %%
phi = -180/6 
theta = -180/4 

#=========define the array========="
x = np.sin(phi)*np.cos(theta)
y = np.sin(phi)*np.sin(theta)
z = np.cos(phi)

problem20 = np.array([x,y,z])
#============print vectors======""
print("x=", x)
print("y=", y)
print("z=", z)

print("================")
print(problem20)
print("================")
print(type(problem20))

#=========print bloch sphere================""
plot_bloch_vector(problem20, title = "problem20")
# Out:
# x= 0.5190347377832737
# y= -0.8407195912917853
# z= 0.15425144988758405
# ...
# [ 0.51903474 -0.84071959  0.15425145]
# ...
# <class 'numpy.ndarray'>
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:397: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   self.axes = Axes3D(self.fig, azim=self.view[0], elev=self.view[1])
# C:\Users\amrit\AppData\Local\Continuum\anaconda3\envs\uhgquantum\lib\site-packages\qiskit\visualization\bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
# ...

# %% [markdown]
# ![the-end](img/the-end.png "the-end")
